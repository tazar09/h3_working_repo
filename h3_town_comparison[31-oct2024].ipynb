# %% [markdown]
# <a href="https://colab.research.google.com/github/tazar09/h3_working_repo/blob/main/h3_town_comparison%5B31-oct2024%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'https://heroes.thelazy.net/index.php/Town_Comparison'

# %%
df0 = pd.read_html(url)[0]

# %%
df = df0.copy()

# %%
df = df.droplevel(level = 0, axis =1)
df = df.drop(0, axis = 0)
df = df.drop(11, axis = 0)

# %%
df.columns = ['town', 'mage_guild', 'silo', 'war_machine', 'week_gold',
       'week_res', 'dwell_ai_val', 'cost_gold', 'cost_wood_ore',
       'cost_res', 'wood', 'mercury',  'ore', 'sulf', 'crystal','gems']
df = df.drop(['war_machine'], axis = 1)

# %%
resource_silo = {'1 , 1': 'w/o', '1': 'res'}

# %%
df['silo'] = df['silo'].replace(resource_silo)
df['mage_guild'] = df['mage_guild'].str.replace('[^\d\.]+', '', regex=True)

# %%
df['week_gold'] = df['week_gold'].apply(lambda x: str.split(x)[0])
df['week_res'] = df['week_res'].apply(lambda x: str.split(x)[0])
df['dwell_ai_val'] = df['dwell_ai_val'].apply(lambda x: str.split(x)[0])
df['cost_gold'] = df['cost_gold'].apply(lambda x: str.split(x)[0])
df['cost_wood_ore'] = df['cost_wood_ore'].apply(lambda x: str.split(x)[0])
df['cost_res'] = df['cost_res'].apply(lambda x: str.split(x)[0])
df['mercury'] = df['mercury'].apply(lambda x: str.split(x)[0])
df['ore'] = df['ore'].apply(lambda x: str.split(x)[0])
df['sulf'] = df['sulf'].apply(lambda x: str.split(x)[0])
df['crystal'] = df['crystal'].apply(lambda x: str.split(x)[0])

# %%
df.columns
# Out:
# Index(['town', 'mage_guild', 'silo', 'week_gold', 'week_res', 'dwell_ai_val',
#        'cost_gold', 'cost_wood_ore', 'cost_res', 'wood', 'mercury', 'ore',
#        'sulf', 'crystal', 'gems'],
#       dtype='object')

# %%
df.head(20)
# Out:
#           town mage_guild silo week_gold week_res dwell_ai_val cost_gold  \
# 1      Rampart          5  res     26620        4        48410    106000
# 2        Tower          5  res     30800        4        48930    105300
# 3      Inferno          5  res     28090        4        46002    115300
# 4   Necropolis          5  w/o     26920        2        40666     97400
# 5      Dungeon          5  res     27205        4        46708    112400
# 6   Stronghold          3  w/o     24530        2        40098     92200
# 7     Fortress          3  w/o     26660        2        39642     92400
# 8      Conflux          5  res     31100        3        51973    116800
# 9         Cove          4  res     29935        4        47037    108300
# 10     Factory          5  res     35770        6        57292    131900
# 12     Average       4.45    -     28837      3.7      46914.7    108091
#
#    cost_wood_ore cost_res   wood mercury    ore  sulf crystal  gems
# 1            264      200  122.0      30    142    30      95  45.0
# 2            270      229  135.0      48    135    43      49  89.0
# 3            240      199  120.0      85    120    50      28  36.0
# 4            280      192  150.0      59    130    43      45  45.0
# 5            284      199  142.0      40    142    82      32  45.0
# 6            309       85  157.0      10    152    10      50  15.0
# 7            290       98  185.0      29    105    49      10  10.0
# 8            277      196  137.0      90    140    38      33  35.0
# 9            330      145  190.0      23    140    58      37  27.0
# 10           315      220  145.0      45    170    40     100  35.0
# 12         284.4      176  148.2    45.5  136.2  44.1    47.8  38.5

# %%
df = df.drop(index = 12)
for i in ['mage_guild', 'week_gold', 'week_res', 'dwell_ai_val', 'cost_gold', 'cost_wood_ore', 'cost_res', 'wood','mercury', 'ore', 'sulf', 'crystal', 'gems']:
  df[i] = df[i].astype(int)

# %%
df['cost_ai'] = round(df['week_gold']/df['dwell_ai_val'],2)

# %%
# df.sort_values('cost_res_std', ascending = False)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df['cost_res_std'] = scaler.fit_transform(df['cost_res'].values.reshape(-1, 1)).round(2)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df['cost_wood_ore_std'] = scaler.fit_transform(df['cost_wood_ore'].values.reshape(-1, 1)).round(2)

# %%
df.sort_values('mercury', ascending=False)
# Out:
#           town  mage_guild silo  week_gold  week_res  dwell_ai_val  cost_gold  \
# 8      Conflux           5  res      31100         3         51973     116800
# 3      Inferno           5  res      28090         4         46002     115300
# 4   Necropolis           5  w/o      26920         2         40666      97400
# 2        Tower           5  res      30800         4         48930     105300
# 10     Factory           5  res      35770         6         57292     131900
# 5      Dungeon           5  res      27205         4         46708     112400
# 1      Rampart           5  res      26620         4         48410     106000
# 7     Fortress           3  w/o      26660         2         39642      92400
# 9         Cove           4  res      29935         4         47037     108300
# 6   Stronghold           3  w/o      24530         2         40098      92200
#
#     cost_wood_ore  cost_res  wood  mercury  ore  sulf  crystal  gems  cost_ai  \
# 8             277       196   137       90  140    38       33    35     0.60
# 3             240       199   120       85  120    50       28    36     0.61
# 4             280       192   150       59  130    43       45    45     0.66
# 2             270       229   135       48  135    43       49    89     0.63
# 10            315       220   145       45  170    40      100    35     0.62
# 5             284       199   142       40  142    82       32    45     0.58
# 1             264       200   122       30  142    30       95    45     0.55
# 7             290        98   185       29  105    49       10    10     0.67
# 9             330       145   190       23  140    58       37    27     0.64
# 6             309        85   157       10  152    10       50    15     0.61
#
#     cost_res_std  cost_wood_ore_std
# 8           0.42              -0.35
# 3           0.48              -1.83
# 4           0.33              -0.24
# 2           1.11              -0.63
# 10          0.92               1.16
# 5           0.48              -0.08
# 1           0.50              -0.87
# 7          -1.66               0.16
# 9          -0.66               1.76
# 6          -1.93               0.92

# %% [markdown]
# Trying to convert different resources to the same standard:

# %%
lst = []
res = ['mercury', 'sulf', 'crystal', 'gems']


df = df.drop(index = [9,10])
for i in ('mercury', 'sulf', 'crystal', 'gems'):
  lst.append(df[i].sum())
  x = df[i].sum()
  print(i,":", x)

print(sum(lst)/4)
# Out:
# mercury : 391
# sulf : 345
# crystal : 342
# gems : 320
# 349.5

# %%
exchange_rate = {}
for i,j in zip(lst,res):
  print(j, ':', round(i/(sum(lst)/4),2))
  exchange_rate[j] = round(i/(sum(lst)/4),2)
print(exchange_rate)
# Out:
# mercury : 1.12
# sulf : 0.99
# crystal : 0.98
# gems : 0.92
# {'mercury': 1.12, 'sulf': 0.99, 'crystal': 0.98, 'gems': 0.92}

# %%
for i in res:
  df[i] = df[i].apply(lambda x: round(x*exchange_rate[i],1))
df.sort_values('mercury', ascending=False)
# Out:
#          town  mage_guild silo  week_gold  week_res  dwell_ai_val  cost_gold  \
# 8     Conflux           5  res      31100         3         51973     116800
# 3     Inferno           5  res      28090         4         46002     115300
# 4  Necropolis           5  w/o      26920         2         40666      97400
# 2       Tower           5  res      30800         4         48930     105300
# 5     Dungeon           5  res      27205         4         46708     112400
# 1     Rampart           5  res      26620         4         48410     106000
# 7    Fortress           3  w/o      26660         2         39642      92400
# 6  Stronghold           3  w/o      24530         2         40098      92200
#
#    cost_wood_ore  cost_res  wood  mercury  ore  sulf  crystal  gems  cost_ai  \
# 8            277       196   137    100.8  140  37.6     32.3  32.2     0.60
# 3            240       199   120     95.2  120  49.5     27.4  33.1     0.61
# 4            280       192   150     66.1  130  42.6     44.1  41.4     0.66
# 2            270       229   135     53.8  135  42.6     48.0  81.9     0.63
# 5            284       199   142     44.8  142  81.2     31.4  41.4     0.58
# 1            264       200   122     33.6  142  29.7     93.1  41.4     0.55
# 7            290        98   185     32.5  105  48.5      9.8   9.2     0.67
# 6            309        85   157     11.2  152   9.9     49.0  13.8     0.61
#
#    cost_res_std  cost_wood_ore_std
# 8          0.42              -0.35
# 3          0.48              -1.83
# 4          0.33              -0.24
# 2          1.11              -0.63
# 5          0.48              -0.08
# 1          0.50              -0.87
# 7         -1.66               0.16
# 6         -1.93               0.92

# %%
90*1.16
# Out:
# 104.39999999999999
